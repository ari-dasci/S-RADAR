# %%
# %reload_ext autoreload
# temporary solution for relative imports in case sadl is not installed
# if sadl is installed, no need to use the line
import sys
import os
import inspect
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

from SADL.static_data.algorithms import pyod

kwargs = {"algorithm": "abod","contamination":0.5, "label_parser": True, "n_neighbors": 4}
model = pyod.PyodAnomalyDetection(**kwargs)

print(model.algorithm.__class__.__name__)
print(model.model)
#inspect.signature(pyod.PyodAnomalyDetection.__init__)
# Out:
# <class 'pyod.models.abod.ABOD'>
# ABOD(contamination=0.5, method='fast', n_neighbors=4)

# %%
from pyod.models import cblof
from pyod.models.abod import ABOD
import inspect
inspect.signature(ABOD.__init__)
# Out:
# <Signature (self, contamination=0.1, n_neighbors=5, method='fast')>
